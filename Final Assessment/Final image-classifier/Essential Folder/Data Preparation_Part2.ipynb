# %%
import torchvision
import torch
import torchvision.transforms as transforms
import os
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import ssl
# Tell Python to ignore the broken network SSL certificates for downloads
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# 1. FIXED: Removed Path.home() so Python targets your actual C drive directories directly
train_dataset_path = r"C:\School\Year 3\Semester 1\EGL 314 - Media Solutioning & Project 1\Project\Dataset\Training"
test_dataset_path =  r"C:\School\Year 3\Semester 1\EGL 314 - Media Solutioning & Project 1\Project\Dataset\Validation"

# %%
mean = [0.4363, 0.4328, 0.3291]
std = [0.2129, 0.2075, 0.2037]

train_transforms = transforms.Compose([
    # 1. Start with a slightly larger size (256x256)
    transforms.Resize((256, 256)), 
    
    # 2. Randomly slice out a 224x224 frame. This forces the stationary 
    # background wall lines to bounce up, down, left, and right on every epoch!
    transforms.RandomCrop((224, 224)),
    
    # 3. Distort the shadows and brightness aggressively
    transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.3, hue=0.1),
    
    # 4. Flips, tilts, and position alignments
    transforms.RandomHorizontalFlip(), 
    transforms.RandomRotation(15), 
    
    transforms.ToTensor(), 
    transforms.Normalize(torch.Tensor(mean), torch.Tensor(std))
])

test_transforms = transforms.Compose([
    # Test images don't need random movement; they just get resized directly to 224x224
    transforms.Resize((224,224)), 
    transforms.ToTensor(),
    transforms.Normalize(torch.Tensor(mean), torch.Tensor(std))
])

# %%
train_dataset = torchvision.datasets.ImageFolder(root = train_dataset_path, transform = train_transforms)
test_dataset = torchvision.datasets.ImageFolder(root = train_dataset_path, transform = train_transforms)

# %%
def show_transformed_images(dataset):
    loader = torch.utils.data.DataLoader(dataset, batch_size = 6, shuffle=True) # Hold 6 randomn images from dataset
    batch = next(iter(loader)) # Grabbing 6 images next
    images, labels = batch

    grid = torchvision.utils.make_grid(images, nrow = 3) #Take the 6 img and create a 2x3 grid of pic
    plt.figure(figsize=(11,11))
    plt.imshow(np.transpose(grid, (1,2,0))) #pytorch read the colour channel first from this (rgb,w,h). plt print the pic,np.transpose rearrange data to display good on monitor
    print ('labels: ',labels) #prints numbers so i can verify the img match up with the correct category

# %%
show_transformed_images(train_dataset)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0857832..3.2935688].
# labels:  tensor([6, 5, 4, 3, 1, 3])

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = 32, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset,batch_size = 32,shuffle=False)

# %%
def set_device():
    if torch.cuda.is_available():
        dev = "cuda:0" #gpu
    else:
        dev = "cpu" #cpu
    return torch.device(dev)

# %%
def train_nn(model, train_loader, test_loader, criterion, optimizer, n_epochs):
    device = set_device()
    best_acc = 0

    for epoch in range(n_epochs): #epoch is a full trip in dataset
        print ("Epoch number %d " % (epoch + 1))
        model.train()
        running_loss = 0.0
        running_correct = 0.0
        total = 0

        for data in train_loader: #Every data in train loader
            images, labels = data
            images = images.to(device) #moves img & ans to gpu
            labels = labels.to(device) #moves img & ans to gpu
            total += labels.size(0)

            optimizer.zero_grad() #clears grade so previous batch old mistake dont get consufed with new mat
            outputs = model(images)

            _ , predicted = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels) 
            loss.backward()# AI checks the criterion and sees how wrong it is and tracks the error backwards
            optimizer.step() #Tweaks internal weight so that it can guess better next time

            running_loss += loss.item() # Adds up the bad guesses
            running_correct += (labels==predicted).sum().item() #looks at all the 32 img and sums how many the ai got right and put in a scoreboard

            epoch_loss = running_loss/len(train_loader)
            epoch_acc = 100.00 * running_correct / total
            print("    - Training dataset. Got %d out of %d images correctly (%.3f%%). Epoch loss: %.3f" % (running_correct, total, epoch_acc, epoch_loss))
            
    test_dataset_acc = evaluate_model_on_test_set(model, test_loader) # AI tests itself using the pic it never seen b4.. if its score higher than prev score, it saves a backup of its brain so that will always have the best answers

    if(test_dataset_acc > best_acc):
        best_acc = test_dataset_acc
        save_checkpoint(model,epoch,optimizer,best_acc)

    print("Finished")
    return model

# %%
def evaluate_model_on_test_set(model, test_loader): 
        model.eval() # It is the testing mode
        predicted_correctly_on_epoch = 0
        total = 0
        device = set_device()

        with torch.no_grad(): # Like a exam closed book, no more learning  and do what uk
               for data in test_loader:
                    images, labels = data
                    images = images.to(device)
                    labels = labels.to(device)
                    total += labels.size(0)
                    
                    outputs = model(images)

                    _, predicted = torch.max(outputs.data, 1) # Gives results and shows how much it got
                    predicted_correctly_on_epoch += (predicted == labels).sum().item()
        epoch_acc = 100.0 * predicted_correctly_on_epoch / total
        print("    - Testing dataset. Got %d out of %d images correctly (%.3f%%)"
                % (predicted_correctly_on_epoch, total, epoch_acc))
        return epoch_acc

# %%
def save_checkpoint(model,epoch,optimizer,best_acc): #saves checkpoints
    state = {
        'epoch' : epoch + 1, # Saves the best epoch.. if got smt higher, it will update to it
        'model' : model.state_dict(), #Extracts the knowledge the ai learnt
        'best accuracy' : best_acc, # Saves the highest score precentage
        'optimizer' : optimizer.state_dict(), # saves the exact state of the learning engine( tracking how fast / slow it was adjusting its brain)
        'comments' : 'very cool model!'   
        }
    torch.save(state, 'model_best_checkpoint.pth.tar') # saves as a file

# %%
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim

resnet18_model = models.resnet18(weights='IMAGENET1K_V1') # a neural network have has millions of images and knows how to recognise alot of things
num_ftrs = resnet18_model.fc.in_features
number_of_classes = 10 # resnet18 was trained to guess alot of abj.. so it is tailored to exacly 10 types images that i have
resnet18_model.fc = nn.Linear(num_ftrs, number_of_classes)
device = set_device() # AI brain moves into the gpu, math-ing faster
resnet_18_model = resnet18_model.to(device)
loss_fn = nn.CrossEntropyLoss() #sees how far the AI guess are from the correct ans

optimizer = optim.SGD(resnet18_model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.003) #SGD algorithm to tweak the learning rate to make sure AI gets it right the next time

# %%
train_nn(resnet18_model, train_loader, test_loader, loss_fn, optimizer, 10)
# Out:
# Epoch number 1
#     - Training dataset. Got 3 out of 32 images correctly (9.375%). Epoch loss: 0.029
#     - Training dataset. Got 8 out of 64 images correctly (12.500%). Epoch loss: 0.055
#     - Training dataset. Got 21 out of 96 images correctly (21.875%). Epoch loss: 0.075
#     - Training dataset. Got 35 out of 128 images correctly (27.344%). Epoch loss: 0.098
#     - Training dataset. Got 49 out of 160 images correctly (30.625%). Epoch loss: 0.117
#     - Training dataset. Got 69 out of 192 images correctly (35.938%). Epoch loss: 0.131
#     - Training dataset. Got 77 out of 224 images correctly (34.375%). Epoch loss: 0.150
#     - Training dataset. Got 96 out of 256 images correctly (37.500%). Epoch loss: 0.165
#     - Training dataset. Got 112 out of 288 images correctly (38.889%). Epoch loss: 0.179
#     - Training dataset. Got 126 out of 320 images correctly (39.375%). Epoch loss: 0.192
#     - Training dataset. Got 153 out of 352 images correctly (43.466%). Epoch loss: 0.200
#     - Training dataset. Got 177 out of 384 images correctly (46.094%). Epoch loss: 0.208
#     - Training dataset. Got 207 out of 416 images correctly (49.760%). Epoch loss: 0.215
#     - Training dataset. Got 236 out of 448 images correctly (52.679%). Epoch loss: 0.220
#     - Training dataset. Got 266 out of 480 images correctly (55.417%). Epoch loss: 0.224
#     - Training dataset. Got 294 out of 512 images correctly (57.422%). Epoch loss: 0.228
#     - Training dataset. Got 320 out of 544 images correctly (58.824%). Epoch loss: 0.236
#     - Training dataset. Got 350 out of 576 images correctly (60.764%). Epoch loss: 0.239
#     - Training dataset. Got 378 out of 608 images correctly (62.171%). Epoch loss: 0.243
#     - Training dataset. Got 409 out of 640 images correctly (63.906%). Epoch loss: 0.244
#     - Training dataset. Got 437 out of 672 images correctly (65.030%). Epoch loss: 0.248
#     - Training dataset. Got 466 out of 704 images correctly (66.193%). Epoch loss: 0.251
#     - Training dataset. Got 497 out of 736 images correctly (67.527%). Epoch loss: 0.252
#     - Training dataset. Got 527 out of 768 images correctly (68.620%). Epoch loss: 0.254
#     - Training dataset. Got 557 out of 800 images correctly (69.625%). Epoch loss: 0.256
#     - Training dataset. Got 588 out of 832 images correctly (70.673%). Epoch loss: 0.257
#     - Training dataset. Got 619 out of 864 images correctly (71.644%). Epoch loss: 0.259
#     - Training dataset. Got 651 out of 896 images correctly (72.656%). Epoch loss: 0.259
#     - Training dataset. Got 683 out of 928 images correctly (73.599%). Epoch loss: 0.260
#     - Training dataset. Got 715 out of 960 images correctly (74.479%). Epoch loss: 0.260
#     - Training dataset. Got 747 out of 992 images correctly (75.302%). Epoch loss: 0.260
#     - Training dataset. Got 778 out of 1024 images correctly (75.977%). Epoch loss: 0.262
#     - Training dataset. Got 810 out of 1056 images correctly (76.705%). Epoch loss: 0.263
#     - Training dataset. Got 842 out of 1088 images correctly (77.390%). Epoch loss: 0.263
#     - Training dataset. Got 874 out of 1120 images correctly (78.036%). Epoch loss: 0.263
#     - Training dataset. Got 906 out of 1152 images correctly (78.646%). Epoch loss: 0.264
#     - Training dataset. Got 938 out of 1184 images correctly (79.223%). Epoch loss: 0.264
#     - Training dataset. Got 968 out of 1216 images correctly (79.605%). Epoch loss: 0.265
#     - Training dataset. Got 999 out of 1248 images correctly (80.048%). Epoch loss: 0.266
#     - Training dataset. Got 1031 out of 1280 images correctly (80.547%). Epoch loss: 0.266
#     - Training dataset. Got 1061 out of 1312 images correctly (80.869%). Epoch loss: 0.269
#     - Training dataset. Got 1093 out of 1344 images correctly (81.324%). Epoch loss: 0.269
#     - Training dataset. Got 1125 out of 1376 images correctly (81.759%). Epoch loss: 0.269
#     - Training dataset. Got 1157 out of 1408 images correctly (82.173%). Epoch loss: 0.270
#     - Training dataset. Got 1187 out of 1440 images correctly (82.431%). Epoch loss: 0.272
#     - Training dataset. Got 1219 out of 1472 images correctly (82.812%). Epoch loss: 0.272
#     - Training dataset. Got 1251 out of 1504 images correctly (83.178%). Epoch loss: 0.272
#     - Training dataset. Got 1283 out of 1536 images correctly (83.529%). Epoch loss: 0.273
#     - Training dataset. Got 1314 out of 1568 images correctly (83.801%). Epoch loss: 0.273
#     - Training dataset. Got 1346 out of 1600 images correctly (84.125%). Epoch loss: 0.273
#     - Training dataset. Got 1378 out of 1632 images correctly (84.436%). Epoch loss: 0.273
#     - Training dataset. Got 1409 out of 1664 images correctly (84.675%). Epoch loss: 0.275
#     - Training dataset. Got 1441 out of 1696 images correctly (84.965%). Epoch loss: 0.275
#     - Training dataset. Got 1472 out of 1728 images correctly (85.185%). Epoch loss: 0.276
#     - Training dataset. Got 1504 out of 1760 images correctly (85.455%). Epoch loss: 0.276
#     - Training dataset. Got 1536 out of 1792 images correctly (85.714%). Epoch loss: 0.276
#     - Training dataset. Got 1565 out of 1824 images correctly (85.800%). Epoch loss: 0.281
#     - Training dataset. Got 1596 out of 1856 images correctly (85.991%). Epoch loss: 0.282
#     - Training dataset. Got 1627 out of 1888 images correctly (86.176%). Epoch loss: 0.283
#     - Training dataset. Got 1659 out of 1920 images correctly (86.406%). Epoch loss: 0.284
#     - Training dataset. Got 1689 out of 1952 images correctly (86.527%). Epoch loss: 0.285
#     - Training dataset. Got 1721 out of 1984 images correctly (86.744%). Epoch loss: 0.286
#     - Training dataset. Got 1753 out of 2016 images correctly (86.954%). Epoch loss: 0.286
#     - Training dataset. Got 1785 out of 2048 images correctly (87.158%). Epoch loss: 0.286
#     - Training dataset. Got 1816 out of 2080 images correctly (87.308%). Epoch loss: 0.287
#     - Training dataset. Got 1846 out of 2112 images correctly (87.405%). Epoch loss: 0.289
#     - Training dataset. Got 1876 out of 2144 images correctly (87.500%). Epoch loss: 0.291
#     - Training dataset. Got 1904 out of 2176 images correctly (87.500%). Epoch loss: 0.294
#     - Training dataset. Got 1936 out of 2208 images correctly (87.681%). Epoch loss: 0.294
#     - Training dataset. Got 1967 out of 2240 images correctly (87.812%). Epoch loss: 0.295
#     - Training dataset. Got 1997 out of 2272 images correctly (87.896%). Epoch loss: 0.296
#     - Training dataset. Got 2028 out of 2304 images correctly (88.021%). Epoch loss: 0.297
#     - Training dataset. Got 2060 out of 2336 images correctly (88.185%). Epoch loss: 0.297
#     - Training dataset. Got 2092 out of 2368 images correctly (88.345%). Epoch loss: 0.297
#     - Training dataset. Got 2121 out of 2400 images correctly (88.375%). Epoch loss: 0.299
#     - Training dataset. Got 2153 out of 2432 images correctly (88.528%). Epoch loss: 0.299
#     - Training dataset. Got 2185 out of 2464 images correctly (88.677%). Epoch loss: 0.300
#     - Training dataset. Got 2216 out of 2496 images correctly (88.782%). Epoch loss: 0.302
#     - Training dataset. Got 2247 out of 2528 images correctly (88.884%). Epoch loss: 0.303
#     - Training dataset. Got 2279 out of 2560 images correctly (89.023%). Epoch loss: 0.303
#     - Training dataset. Got 2311 out of 2592 images correctly (89.159%). Epoch loss: 0.304
#     - Training dataset. Got 2343 out of 2624 images correctly (89.291%). Epoch loss: 0.304
#     - Training dataset. Got 2375 out of 2656 images correctly (89.420%). Epoch loss: 0.304
#     - Training dataset. Got 2406 out of 2688 images correctly (89.509%). Epoch loss: 0.305
#     - Training dataset. Got 2434 out of 2716 images correctly (89.617%). Epoch loss: 0.305
# Epoch number 2
#     - Training dataset. Got 32 out of 32 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 62 out of 64 images correctly (96.875%). Epoch loss: 0.003
#     - Training dataset. Got 94 out of 96 images correctly (97.917%). Epoch loss: 0.003
#     - Training dataset. Got 125 out of 128 images correctly (97.656%). Epoch loss: 0.003
#     - Training dataset. Got 155 out of 160 images correctly (96.875%). Epoch loss: 0.004
#     - Training dataset. Got 187 out of 192 images correctly (97.396%). Epoch loss: 0.005
#     - Training dataset. Got 219 out of 224 images correctly (97.768%). Epoch loss: 0.005
#     - Training dataset. Got 250 out of 256 images correctly (97.656%). Epoch loss: 0.006
#     - Training dataset. Got 282 out of 288 images correctly (97.917%). Epoch loss: 0.006
#     - Training dataset. Got 313 out of 320 images correctly (97.812%). Epoch loss: 0.007
#     - Training dataset. Got 344 out of 352 images correctly (97.727%). Epoch loss: 0.008
#     - Training dataset. Got 376 out of 384 images correctly (97.917%). Epoch loss: 0.008
#     - Training dataset. Got 408 out of 416 images correctly (98.077%). Epoch loss: 0.008
#     - Training dataset. Got 440 out of 448 images correctly (98.214%). Epoch loss: 0.009
#     - Training dataset. Got 472 out of 480 images correctly (98.333%). Epoch loss: 0.009
#     - Training dataset. Got 504 out of 512 images correctly (98.438%). Epoch loss: 0.009
#     - Training dataset. Got 535 out of 544 images correctly (98.346%). Epoch loss: 0.011
#     - Training dataset. Got 567 out of 576 images correctly (98.438%). Epoch loss: 0.011
#     - Training dataset. Got 599 out of 608 images correctly (98.520%). Epoch loss: 0.011
#     - Training dataset. Got 631 out of 640 images correctly (98.594%). Epoch loss: 0.011
#     - Training dataset. Got 663 out of 672 images correctly (98.661%). Epoch loss: 0.011
#     - Training dataset. Got 695 out of 704 images correctly (98.722%). Epoch loss: 0.011
#     - Training dataset. Got 727 out of 736 images correctly (98.777%). Epoch loss: 0.011
#     - Training dataset. Got 759 out of 768 images correctly (98.828%). Epoch loss: 0.011
#     - Training dataset. Got 791 out of 800 images correctly (98.875%). Epoch loss: 0.012
#     - Training dataset. Got 822 out of 832 images correctly (98.798%). Epoch loss: 0.012
#     - Training dataset. Got 854 out of 864 images correctly (98.843%). Epoch loss: 0.012
#     - Training dataset. Got 886 out of 896 images correctly (98.884%). Epoch loss: 0.012
#     - Training dataset. Got 917 out of 928 images correctly (98.815%). Epoch loss: 0.013
#     - Training dataset. Got 948 out of 960 images correctly (98.750%). Epoch loss: 0.014
#     - Training dataset. Got 979 out of 992 images correctly (98.690%). Epoch loss: 0.015
#     - Training dataset. Got 1010 out of 1024 images correctly (98.633%). Epoch loss: 0.015
#     - Training dataset. Got 1042 out of 1056 images correctly (98.674%). Epoch loss: 0.015
#     - Training dataset. Got 1074 out of 1088 images correctly (98.713%). Epoch loss: 0.015
#     - Training dataset. Got 1106 out of 1120 images correctly (98.750%). Epoch loss: 0.016
#     - Training dataset. Got 1138 out of 1152 images correctly (98.785%). Epoch loss: 0.016
#     - Training dataset. Got 1170 out of 1184 images correctly (98.818%). Epoch loss: 0.016
#     - Training dataset. Got 1202 out of 1216 images correctly (98.849%). Epoch loss: 0.016
#     - Training dataset. Got 1233 out of 1248 images correctly (98.798%). Epoch loss: 0.017
#     - Training dataset. Got 1265 out of 1280 images correctly (98.828%). Epoch loss: 0.017
#     - Training dataset. Got 1296 out of 1312 images correctly (98.780%). Epoch loss: 0.018
#     - Training dataset. Got 1327 out of 1344 images correctly (98.735%). Epoch loss: 0.022
#     - Training dataset. Got 1359 out of 1376 images correctly (98.765%). Epoch loss: 0.022
#     - Training dataset. Got 1391 out of 1408 images correctly (98.793%). Epoch loss: 0.022
#     - Training dataset. Got 1423 out of 1440 images correctly (98.819%). Epoch loss: 0.022
#     - Training dataset. Got 1455 out of 1472 images correctly (98.845%). Epoch loss: 0.022
#     - Training dataset. Got 1486 out of 1504 images correctly (98.803%). Epoch loss: 0.023
#     - Training dataset. Got 1518 out of 1536 images correctly (98.828%). Epoch loss: 0.023
#     - Training dataset. Got 1550 out of 1568 images correctly (98.852%). Epoch loss: 0.023
#     - Training dataset. Got 1582 out of 1600 images correctly (98.875%). Epoch loss: 0.023
#     - Training dataset. Got 1614 out of 1632 images correctly (98.897%). Epoch loss: 0.023
#     - Training dataset. Got 1646 out of 1664 images correctly (98.918%). Epoch loss: 0.024
#     - Training dataset. Got 1677 out of 1696 images correctly (98.880%). Epoch loss: 0.024
#     - Training dataset. Got 1708 out of 1728 images correctly (98.843%). Epoch loss: 0.025
#     - Training dataset. Got 1740 out of 1760 images correctly (98.864%). Epoch loss: 0.025
#     - Training dataset. Got 1772 out of 1792 images correctly (98.884%). Epoch loss: 0.025
#     - Training dataset. Got 1804 out of 1824 images correctly (98.904%). Epoch loss: 0.025
#     - Training dataset. Got 1836 out of 1856 images correctly (98.922%). Epoch loss: 0.025
#     - Training dataset. Got 1868 out of 1888 images correctly (98.941%). Epoch loss: 0.026
#     - Training dataset. Got 1898 out of 1920 images correctly (98.854%). Epoch loss: 0.027
#     - Training dataset. Got 1930 out of 1952 images correctly (98.873%). Epoch loss: 0.027
#     - Training dataset. Got 1961 out of 1984 images correctly (98.841%). Epoch loss: 0.027
#     - Training dataset. Got 1992 out of 2016 images correctly (98.810%). Epoch loss: 0.028
#     - Training dataset. Got 2023 out of 2048 images correctly (98.779%). Epoch loss: 0.029
#     - Training dataset. Got 2055 out of 2080 images correctly (98.798%). Epoch loss: 0.029
#     - Training dataset. Got 2087 out of 2112 images correctly (98.816%). Epoch loss: 0.029
#     - Training dataset. Got 2118 out of 2144 images correctly (98.787%). Epoch loss: 0.029
#     - Training dataset. Got 2150 out of 2176 images correctly (98.805%). Epoch loss: 0.029
#     - Training dataset. Got 2182 out of 2208 images correctly (98.822%). Epoch loss: 0.030
#     - Training dataset. Got 2213 out of 2240 images correctly (98.795%). Epoch loss: 0.030
#     - Training dataset. Got 2245 out of 2272 images correctly (98.812%). Epoch loss: 0.030
#     - Training dataset. Got 2277 out of 2304 images correctly (98.828%). Epoch loss: 0.031
#     - Training dataset. Got 2309 out of 2336 images correctly (98.844%). Epoch loss: 0.031
#     - Training dataset. Got 2341 out of 2368 images correctly (98.860%). Epoch loss: 0.031
#     - Training dataset. Got 2372 out of 2400 images correctly (98.833%). Epoch loss: 0.032
#     - Training dataset. Got 2404 out of 2432 images correctly (98.849%). Epoch loss: 0.032
#     - Training dataset. Got 2436 out of 2464 images correctly (98.864%). Epoch loss: 0.032
#     - Training dataset. Got 2468 out of 2496 images correctly (98.878%). Epoch loss: 0.033
#     - Training dataset. Got 2499 out of 2528 images correctly (98.853%). Epoch loss: 0.034
#     - Training dataset. Got 2531 out of 2560 images correctly (98.867%). Epoch loss: 0.034
#     - Training dataset. Got 2562 out of 2592 images correctly (98.843%). Epoch loss: 0.034
#     - Training dataset. Got 2594 out of 2624 images correctly (98.857%). Epoch loss: 0.035
#     - Training dataset. Got 2626 out of 2656 images correctly (98.870%). Epoch loss: 0.035
#     - Training dataset. Got 2657 out of 2688 images correctly (98.847%). Epoch loss: 0.035
#     - Training dataset. Got 2684 out of 2716 images correctly (98.822%). Epoch loss: 0.036
# Epoch number 3
#     - Training dataset. Got 32 out of 32 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 62 out of 64 images correctly (96.875%). Epoch loss: 0.001
#     - Training dataset. Got 94 out of 96 images correctly (97.917%). Epoch loss: 0.002
#     - Training dataset. Got 126 out of 128 images correctly (98.438%). Epoch loss: 0.002
#     - Training dataset. Got 157 out of 160 images correctly (98.125%). Epoch loss: 0.002
#     - Training dataset. Got 189 out of 192 images correctly (98.438%). Epoch loss: 0.002
#     - Training dataset. Got 221 out of 224 images correctly (98.661%). Epoch loss: 0.002
#     - Training dataset. Got 253 out of 256 images correctly (98.828%). Epoch loss: 0.002
#     - Training dataset. Got 285 out of 288 images correctly (98.958%). Epoch loss: 0.002
#     - Training dataset. Got 317 out of 320 images correctly (99.062%). Epoch loss: 0.002
#     - Training dataset. Got 349 out of 352 images correctly (99.148%). Epoch loss: 0.002
#     - Training dataset. Got 380 out of 384 images correctly (98.958%). Epoch loss: 0.003
#     - Training dataset. Got 412 out of 416 images correctly (99.038%). Epoch loss: 0.003
#     - Training dataset. Got 444 out of 448 images correctly (99.107%). Epoch loss: 0.004
#     - Training dataset. Got 476 out of 480 images correctly (99.167%). Epoch loss: 0.004
#     - Training dataset. Got 506 out of 512 images correctly (98.828%). Epoch loss: 0.005
#     - Training dataset. Got 538 out of 544 images correctly (98.897%). Epoch loss: 0.005
#     - Training dataset. Got 570 out of 576 images correctly (98.958%). Epoch loss: 0.005
#     - Training dataset. Got 602 out of 608 images correctly (99.013%). Epoch loss: 0.005
#     - Training dataset. Got 634 out of 640 images correctly (99.062%). Epoch loss: 0.005
#     - Training dataset. Got 666 out of 672 images correctly (99.107%). Epoch loss: 0.005
#     - Training dataset. Got 698 out of 704 images correctly (99.148%). Epoch loss: 0.005
#     - Training dataset. Got 729 out of 736 images correctly (99.049%). Epoch loss: 0.007
#     - Training dataset. Got 761 out of 768 images correctly (99.089%). Epoch loss: 0.007
#     - Training dataset. Got 792 out of 800 images correctly (99.000%). Epoch loss: 0.007
#     - Training dataset. Got 824 out of 832 images correctly (99.038%). Epoch loss: 0.008
#     - Training dataset. Got 856 out of 864 images correctly (99.074%). Epoch loss: 0.008
#     - Training dataset. Got 888 out of 896 images correctly (99.107%). Epoch loss: 0.008
#     - Training dataset. Got 920 out of 928 images correctly (99.138%). Epoch loss: 0.008
#     - Training dataset. Got 952 out of 960 images correctly (99.167%). Epoch loss: 0.008
#     - Training dataset. Got 984 out of 992 images correctly (99.194%). Epoch loss: 0.008
#     - Training dataset. Got 1016 out of 1024 images correctly (99.219%). Epoch loss: 0.008
#     - Training dataset. Got 1047 out of 1056 images correctly (99.148%). Epoch loss: 0.009
#     - Training dataset. Got 1079 out of 1088 images correctly (99.173%). Epoch loss: 0.009
#     - Training dataset. Got 1111 out of 1120 images correctly (99.196%). Epoch loss: 0.009
#     - Training dataset. Got 1143 out of 1152 images correctly (99.219%). Epoch loss: 0.009
#     - Training dataset. Got 1175 out of 1184 images correctly (99.240%). Epoch loss: 0.009
#     - Training dataset. Got 1207 out of 1216 images correctly (99.260%). Epoch loss: 0.009
#     - Training dataset. Got 1239 out of 1248 images correctly (99.279%). Epoch loss: 0.009
#     - Training dataset. Got 1271 out of 1280 images correctly (99.297%). Epoch loss: 0.009
#     - Training dataset. Got 1303 out of 1312 images correctly (99.314%). Epoch loss: 0.009
#     - Training dataset. Got 1335 out of 1344 images correctly (99.330%). Epoch loss: 0.009
#     - Training dataset. Got 1367 out of 1376 images correctly (99.346%). Epoch loss: 0.010
#     - Training dataset. Got 1397 out of 1408 images correctly (99.219%). Epoch loss: 0.011
#     - Training dataset. Got 1429 out of 1440 images correctly (99.236%). Epoch loss: 0.011
#     - Training dataset. Got 1461 out of 1472 images correctly (99.253%). Epoch loss: 0.012
#     - Training dataset. Got 1492 out of 1504 images correctly (99.202%). Epoch loss: 0.012
#     - Training dataset. Got 1524 out of 1536 images correctly (99.219%). Epoch loss: 0.012
#     - Training dataset. Got 1556 out of 1568 images correctly (99.235%). Epoch loss: 0.012
#     - Training dataset. Got 1588 out of 1600 images correctly (99.250%). Epoch loss: 0.012
#     - Training dataset. Got 1620 out of 1632 images correctly (99.265%). Epoch loss: 0.013
#     - Training dataset. Got 1652 out of 1664 images correctly (99.279%). Epoch loss: 0.013
#     - Training dataset. Got 1684 out of 1696 images correctly (99.292%). Epoch loss: 0.013
#     - Training dataset. Got 1715 out of 1728 images correctly (99.248%). Epoch loss: 0.014
#     - Training dataset. Got 1747 out of 1760 images correctly (99.261%). Epoch loss: 0.014
#     - Training dataset. Got 1779 out of 1792 images correctly (99.275%). Epoch loss: 0.014
#     - Training dataset. Got 1811 out of 1824 images correctly (99.287%). Epoch loss: 0.014
#     - Training dataset. Got 1843 out of 1856 images correctly (99.300%). Epoch loss: 0.014
#     - Training dataset. Got 1875 out of 1888 images correctly (99.311%). Epoch loss: 0.014
#     - Training dataset. Got 1907 out of 1920 images correctly (99.323%). Epoch loss: 0.014
#     - Training dataset. Got 1938 out of 1952 images correctly (99.283%). Epoch loss: 0.015
#     - Training dataset. Got 1969 out of 1984 images correctly (99.244%). Epoch loss: 0.015
#     - Training dataset. Got 2001 out of 2016 images correctly (99.256%). Epoch loss: 0.015
#     - Training dataset. Got 2033 out of 2048 images correctly (99.268%). Epoch loss: 0.015
#     - Training dataset. Got 2065 out of 2080 images correctly (99.279%). Epoch loss: 0.015
#     - Training dataset. Got 2097 out of 2112 images correctly (99.290%). Epoch loss: 0.015
#     - Training dataset. Got 2129 out of 2144 images correctly (99.300%). Epoch loss: 0.015
#     - Training dataset. Got 2161 out of 2176 images correctly (99.311%). Epoch loss: 0.016
#     - Training dataset. Got 2193 out of 2208 images correctly (99.321%). Epoch loss: 0.016
#     - Training dataset. Got 2225 out of 2240 images correctly (99.330%). Epoch loss: 0.016
#     - Training dataset. Got 2257 out of 2272 images correctly (99.340%). Epoch loss: 0.016
#     - Training dataset. Got 2289 out of 2304 images correctly (99.349%). Epoch loss: 0.016
#     - Training dataset. Got 2321 out of 2336 images correctly (99.358%). Epoch loss: 0.016
#     - Training dataset. Got 2353 out of 2368 images correctly (99.367%). Epoch loss: 0.016
#     - Training dataset. Got 2385 out of 2400 images correctly (99.375%). Epoch loss: 0.016
#     - Training dataset. Got 2417 out of 2432 images correctly (99.383%). Epoch loss: 0.016
#     - Training dataset. Got 2449 out of 2464 images correctly (99.391%). Epoch loss: 0.016
#     - Training dataset. Got 2481 out of 2496 images correctly (99.399%). Epoch loss: 0.016
#     - Training dataset. Got 2513 out of 2528 images correctly (99.407%). Epoch loss: 0.016
#     - Training dataset. Got 2545 out of 2560 images correctly (99.414%). Epoch loss: 0.016
#     - Training dataset. Got 2576 out of 2592 images correctly (99.383%). Epoch loss: 0.017
#     - Training dataset. Got 2608 out of 2624 images correctly (99.390%). Epoch loss: 0.017
#     - Training dataset. Got 2640 out of 2656 images correctly (99.398%). Epoch loss: 0.017
#     - Training dataset. Got 2672 out of 2688 images correctly (99.405%). Epoch loss: 0.017
#     - Training dataset. Got 2700 out of 2716 images correctly (99.411%). Epoch loss: 0.017
# Epoch number 4
#     - Training dataset. Got 32 out of 32 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 64 out of 64 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 96 out of 96 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 128 out of 128 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 160 out of 160 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 192 out of 192 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 224 out of 224 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 256 out of 256 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 288 out of 288 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 320 out of 320 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 352 out of 352 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 384 out of 384 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 416 out of 416 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 448 out of 448 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 480 out of 480 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 512 out of 512 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 544 out of 544 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 576 out of 576 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 608 out of 608 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 640 out of 640 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 672 out of 672 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 704 out of 704 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 736 out of 736 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 768 out of 768 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 800 out of 800 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 832 out of 832 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 864 out of 864 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 896 out of 896 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 928 out of 928 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 960 out of 960 images correctly (100.000%). Epoch loss: 0.001
#     - Training dataset. Got 991 out of 992 images correctly (99.899%). Epoch loss: 0.002
#     - Training dataset. Got 1022 out of 1024 images correctly (99.805%). Epoch loss: 0.003
#     - Training dataset. Got 1054 out of 1056 images correctly (99.811%). Epoch loss: 0.003
#     - Training dataset. Got 1086 out of 1088 images correctly (99.816%). Epoch loss: 0.003
#     - Training dataset. Got 1116 out of 1120 images correctly (99.643%). Epoch loss: 0.005
#     - Training dataset. Got 1148 out of 1152 images correctly (99.653%). Epoch loss: 0.005
#     - Training dataset. Got 1180 out of 1184 images correctly (99.662%). Epoch loss: 0.005
#     - Training dataset. Got 1212 out of 1216 images correctly (99.671%). Epoch loss: 0.005
#     - Training dataset. Got 1244 out of 1248 images correctly (99.679%). Epoch loss: 0.006
#     - Training dataset. Got 1276 out of 1280 images correctly (99.688%). Epoch loss: 0.006
#     - Training dataset. Got 1308 out of 1312 images correctly (99.695%). Epoch loss: 0.006
#     - Training dataset. Got 1340 out of 1344 images correctly (99.702%). Epoch loss: 0.006
#     - Training dataset. Got 1371 out of 1376 images correctly (99.637%). Epoch loss: 0.006
#     - Training dataset. Got 1403 out of 1408 images correctly (99.645%). Epoch loss: 0.007
#     - Training dataset. Got 1435 out of 1440 images correctly (99.653%). Epoch loss: 0.007
#     - Training dataset. Got 1466 out of 1472 images correctly (99.592%). Epoch loss: 0.008
#     - Training dataset. Got 1498 out of 1504 images correctly (99.601%). Epoch loss: 0.008
#     - Training dataset. Got 1530 out of 1536 images correctly (99.609%). Epoch loss: 0.009
#     - Training dataset. Got 1562 out of 1568 images correctly (99.617%). Epoch loss: 0.009
#     - Training dataset. Got 1594 out of 1600 images correctly (99.625%). Epoch loss: 0.009
#     - Training dataset. Got 1626 out of 1632 images correctly (99.632%). Epoch loss: 0.009
#     - Training dataset. Got 1658 out of 1664 images correctly (99.639%). Epoch loss: 0.009
#     - Training dataset. Got 1690 out of 1696 images correctly (99.646%). Epoch loss: 0.009
#     - Training dataset. Got 1722 out of 1728 images correctly (99.653%). Epoch loss: 0.009
#     - Training dataset. Got 1754 out of 1760 images correctly (99.659%). Epoch loss: 0.009
#     - Training dataset. Got 1786 out of 1792 images correctly (99.665%). Epoch loss: 0.009
#     - Training dataset. Got 1818 out of 1824 images correctly (99.671%). Epoch loss: 0.009
#     - Training dataset. Got 1849 out of 1856 images correctly (99.623%). Epoch loss: 0.010
#     - Training dataset. Got 1880 out of 1888 images correctly (99.576%). Epoch loss: 0.011
#     - Training dataset. Got 1912 out of 1920 images correctly (99.583%). Epoch loss: 0.011
#     - Training dataset. Got 1944 out of 1952 images correctly (99.590%). Epoch loss: 0.011
#     - Training dataset. Got 1976 out of 1984 images correctly (99.597%). Epoch loss: 0.011
#     - Training dataset. Got 2008 out of 2016 images correctly (99.603%). Epoch loss: 0.011
#     - Training dataset. Got 2040 out of 2048 images correctly (99.609%). Epoch loss: 0.011
#     - Training dataset. Got 2071 out of 2080 images correctly (99.567%). Epoch loss: 0.011
#     - Training dataset. Got 2103 out of 2112 images correctly (99.574%). Epoch loss: 0.011
#     - Training dataset. Got 2134 out of 2144 images correctly (99.534%). Epoch loss: 0.012
#     - Training dataset. Got 2166 out of 2176 images correctly (99.540%). Epoch loss: 0.012
#     - Training dataset. Got 2198 out of 2208 images correctly (99.547%). Epoch loss: 0.012
#     - Training dataset. Got 2230 out of 2240 images correctly (99.554%). Epoch loss: 0.013
#     - Training dataset. Got 2262 out of 2272 images correctly (99.560%). Epoch loss: 0.013
#     - Training dataset. Got 2294 out of 2304 images correctly (99.566%). Epoch loss: 0.013
#     - Training dataset. Got 2326 out of 2336 images correctly (99.572%). Epoch loss: 0.013
#     - Training dataset. Got 2358 out of 2368 images correctly (99.578%). Epoch loss: 0.013
#     - Training dataset. Got 2390 out of 2400 images correctly (99.583%). Epoch loss: 0.013
#     - Training dataset. Got 2422 out of 2432 images correctly (99.589%). Epoch loss: 0.013
#     - Training dataset. Got 2454 out of 2464 images correctly (99.594%). Epoch loss: 0.013
#     - Training dataset. Got 2486 out of 2496 images correctly (99.599%). Epoch loss: 0.013
#     - Training dataset. Got 2517 out of 2528 images correctly (99.565%). Epoch loss: 0.014
#     - Training dataset. Got 2549 out of 2560 images correctly (99.570%). Epoch loss: 0.014
#     - Training dataset. Got 2581 out of 2592 images correctly (99.576%). Epoch loss: 0.014
#     - Training dataset. Got 2613 out of 2624 images correctly (99.581%). Epoch loss: 0.014
#     - Training dataset. Got 2645 out of 2656 images correctly (99.586%). Epoch loss: 0.014
#     - Training dataset. Got 2677 out of 2688 images correctly (99.591%). Epoch loss: 0.014
#     - Training dataset. Got 2705 out of 2716 images correctly (99.595%). Epoch loss: 0.014
# Epoch number 5
#     - Training dataset. Got 32 out of 32 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 64 out of 64 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 95 out of 96 images correctly (98.958%). Epoch loss: 0.001
#     - Training dataset. Got 127 out of 128 images correctly (99.219%). Epoch loss: 0.001
#     - Training dataset. Got 159 out of 160 images correctly (99.375%). Epoch loss: 0.001
#     - Training dataset. Got 190 out of 192 images correctly (98.958%). Epoch loss: 0.003
#     - Training dataset. Got 222 out of 224 images correctly (99.107%). Epoch loss: 0.003
#     - Training dataset. Got 254 out of 256 images correctly (99.219%). Epoch loss: 0.003
#     - Training dataset. Got 286 out of 288 images correctly (99.306%). Epoch loss: 0.003
#     - Training dataset. Got 318 out of 320 images correctly (99.375%). Epoch loss: 0.003
#     - Training dataset. Got 350 out of 352 images correctly (99.432%). Epoch loss: 0.003
#     - Training dataset. Got 382 out of 384 images correctly (99.479%). Epoch loss: 0.003
#     - Training dataset. Got 414 out of 416 images correctly (99.519%). Epoch loss: 0.003
#     - Training dataset. Got 446 out of 448 images correctly (99.554%). Epoch loss: 0.003
#     - Training dataset. Got 477 out of 480 images correctly (99.375%). Epoch loss: 0.004
#     - Training dataset. Got 509 out of 512 images correctly (99.414%). Epoch loss: 0.004
#     - Training dataset. Got 541 out of 544 images correctly (99.449%). Epoch loss: 0.004
#     - Training dataset. Got 573 out of 576 images correctly (99.479%). Epoch loss: 0.004
#     - Training dataset. Got 605 out of 608 images correctly (99.507%). Epoch loss: 0.004
#     - Training dataset. Got 637 out of 640 images correctly (99.531%). Epoch loss: 0.004
#     - Training dataset. Got 669 out of 672 images correctly (99.554%). Epoch loss: 0.004
#     - Training dataset. Got 701 out of 704 images correctly (99.574%). Epoch loss: 0.004
#     - Training dataset. Got 733 out of 736 images correctly (99.592%). Epoch loss: 0.004
#     - Training dataset. Got 765 out of 768 images correctly (99.609%). Epoch loss: 0.004
#     - Training dataset. Got 797 out of 800 images correctly (99.625%). Epoch loss: 0.004
#     - Training dataset. Got 829 out of 832 images correctly (99.639%). Epoch loss: 0.004
#     - Training dataset. Got 861 out of 864 images correctly (99.653%). Epoch loss: 0.004
#     - Training dataset. Got 893 out of 896 images correctly (99.665%). Epoch loss: 0.004
#     - Training dataset. Got 925 out of 928 images correctly (99.677%). Epoch loss: 0.004
#     - Training dataset. Got 957 out of 960 images correctly (99.688%). Epoch loss: 0.004
#     - Training dataset. Got 989 out of 992 images correctly (99.698%). Epoch loss: 0.004
#     - Training dataset. Got 1020 out of 1024 images correctly (99.609%). Epoch loss: 0.005
#     - Training dataset. Got 1052 out of 1056 images correctly (99.621%). Epoch loss: 0.005
#     - Training dataset. Got 1084 out of 1088 images correctly (99.632%). Epoch loss: 0.005
#     - Training dataset. Got 1116 out of 1120 images correctly (99.643%). Epoch loss: 0.005
#     - Training dataset. Got 1148 out of 1152 images correctly (99.653%). Epoch loss: 0.005
#     - Training dataset. Got 1180 out of 1184 images correctly (99.662%). Epoch loss: 0.005
#     - Training dataset. Got 1212 out of 1216 images correctly (99.671%). Epoch loss: 0.005
#     - Training dataset. Got 1243 out of 1248 images correctly (99.599%). Epoch loss: 0.006
#     - Training dataset. Got 1275 out of 1280 images correctly (99.609%). Epoch loss: 0.006
#     - Training dataset. Got 1307 out of 1312 images correctly (99.619%). Epoch loss: 0.006
#     - Training dataset. Got 1339 out of 1344 images correctly (99.628%). Epoch loss: 0.006
#     - Training dataset. Got 1371 out of 1376 images correctly (99.637%). Epoch loss: 0.006
#     - Training dataset. Got 1403 out of 1408 images correctly (99.645%). Epoch loss: 0.006
#     - Training dataset. Got 1435 out of 1440 images correctly (99.653%). Epoch loss: 0.006
#     - Training dataset. Got 1467 out of 1472 images correctly (99.660%). Epoch loss: 0.006
#     - Training dataset. Got 1499 out of 1504 images correctly (99.668%). Epoch loss: 0.006
#     - Training dataset. Got 1531 out of 1536 images correctly (99.674%). Epoch loss: 0.006
#     - Training dataset. Got 1563 out of 1568 images correctly (99.681%). Epoch loss: 0.006
#     - Training dataset. Got 1595 out of 1600 images correctly (99.688%). Epoch loss: 0.006
#     - Training dataset. Got 1627 out of 1632 images correctly (99.694%). Epoch loss: 0.006
#     - Training dataset. Got 1659 out of 1664 images correctly (99.700%). Epoch loss: 0.006
#     - Training dataset. Got 1691 out of 1696 images correctly (99.705%). Epoch loss: 0.006
#     - Training dataset. Got 1723 out of 1728 images correctly (99.711%). Epoch loss: 0.006
#     - Training dataset. Got 1754 out of 1760 images correctly (99.659%). Epoch loss: 0.008
#     - Training dataset. Got 1786 out of 1792 images correctly (99.665%). Epoch loss: 0.008
#     - Training dataset. Got 1818 out of 1824 images correctly (99.671%). Epoch loss: 0.008
#     - Training dataset. Got 1850 out of 1856 images correctly (99.677%). Epoch loss: 0.008
#     - Training dataset. Got 1882 out of 1888 images correctly (99.682%). Epoch loss: 0.008
#     - Training dataset. Got 1914 out of 1920 images correctly (99.688%). Epoch loss: 0.008
#     - Training dataset. Got 1946 out of 1952 images correctly (99.693%). Epoch loss: 0.008
#     - Training dataset. Got 1978 out of 1984 images correctly (99.698%). Epoch loss: 0.008
#     - Training dataset. Got 2010 out of 2016 images correctly (99.702%). Epoch loss: 0.008
#     - Training dataset. Got 2042 out of 2048 images correctly (99.707%). Epoch loss: 0.008
#     - Training dataset. Got 2073 out of 2080 images correctly (99.663%). Epoch loss: 0.009
#     - Training dataset. Got 2105 out of 2112 images correctly (99.669%). Epoch loss: 0.009
#     - Training dataset. Got 2137 out of 2144 images correctly (99.674%). Epoch loss: 0.009
#     - Training dataset. Got 2168 out of 2176 images correctly (99.632%). Epoch loss: 0.010
#     - Training dataset. Got 2199 out of 2208 images correctly (99.592%). Epoch loss: 0.010
#     - Training dataset. Got 2231 out of 2240 images correctly (99.598%). Epoch loss: 0.010
#     - Training dataset. Got 2263 out of 2272 images correctly (99.604%). Epoch loss: 0.010
#     - Training dataset. Got 2295 out of 2304 images correctly (99.609%). Epoch loss: 0.011
#     - Training dataset. Got 2327 out of 2336 images correctly (99.615%). Epoch loss: 0.011
#     - Training dataset. Got 2359 out of 2368 images correctly (99.620%). Epoch loss: 0.011
#     - Training dataset. Got 2391 out of 2400 images correctly (99.625%). Epoch loss: 0.011
#     - Training dataset. Got 2423 out of 2432 images correctly (99.630%). Epoch loss: 0.011
#     - Training dataset. Got 2455 out of 2464 images correctly (99.635%). Epoch loss: 0.011
#     - Training dataset. Got 2487 out of 2496 images correctly (99.639%). Epoch loss: 0.011
#     - Training dataset. Got 2516 out of 2528 images correctly (99.525%). Epoch loss: 0.013
#     - Training dataset. Got 2548 out of 2560 images correctly (99.531%). Epoch loss: 0.013
#     - Training dataset. Got 2580 out of 2592 images correctly (99.537%). Epoch loss: 0.013
#     - Training dataset. Got 2612 out of 2624 images correctly (99.543%). Epoch loss: 0.013
#     - Training dataset. Got 2644 out of 2656 images correctly (99.548%). Epoch loss: 0.013
#     - Training dataset. Got 2676 out of 2688 images correctly (99.554%). Epoch loss: 0.013
#     - Training dataset. Got 2704 out of 2716 images correctly (99.558%). Epoch loss: 0.013
# Epoch number 6
#     - Training dataset. Got 32 out of 32 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 64 out of 64 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 96 out of 96 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 128 out of 128 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 159 out of 160 images correctly (99.375%). Epoch loss: 0.001
#     - Training dataset. Got 191 out of 192 images correctly (99.479%). Epoch loss: 0.001
#     - Training dataset. Got 223 out of 224 images correctly (99.554%). Epoch loss: 0.001
#     - Training dataset. Got 255 out of 256 images correctly (99.609%). Epoch loss: 0.001
#     - Training dataset. Got 287 out of 288 images correctly (99.653%). Epoch loss: 0.001
#     - Training dataset. Got 319 out of 320 images correctly (99.688%). Epoch loss: 0.001
#     - Training dataset. Got 351 out of 352 images correctly (99.716%). Epoch loss: 0.001
#     - Training dataset. Got 383 out of 384 images correctly (99.740%). Epoch loss: 0.002
#     - Training dataset. Got 415 out of 416 images correctly (99.760%). Epoch loss: 0.002
#     - Training dataset. Got 447 out of 448 images correctly (99.777%). Epoch loss: 0.002
#     - Training dataset. Got 479 out of 480 images correctly (99.792%). Epoch loss: 0.002
#     - Training dataset. Got 511 out of 512 images correctly (99.805%). Epoch loss: 0.002
#     - Training dataset. Got 543 out of 544 images correctly (99.816%). Epoch loss: 0.002
#     - Training dataset. Got 575 out of 576 images correctly (99.826%). Epoch loss: 0.002
#     - Training dataset. Got 607 out of 608 images correctly (99.836%). Epoch loss: 0.002
#     - Training dataset. Got 639 out of 640 images correctly (99.844%). Epoch loss: 0.002
#     - Training dataset. Got 671 out of 672 images correctly (99.851%). Epoch loss: 0.002
#     - Training dataset. Got 703 out of 704 images correctly (99.858%). Epoch loss: 0.002
#     - Training dataset. Got 735 out of 736 images correctly (99.864%). Epoch loss: 0.002
#     - Training dataset. Got 767 out of 768 images correctly (99.870%). Epoch loss: 0.003
#     - Training dataset. Got 799 out of 800 images correctly (99.875%). Epoch loss: 0.003
#     - Training dataset. Got 831 out of 832 images correctly (99.880%). Epoch loss: 0.003
#     - Training dataset. Got 863 out of 864 images correctly (99.884%). Epoch loss: 0.003
#     - Training dataset. Got 894 out of 896 images correctly (99.777%). Epoch loss: 0.003
#     - Training dataset. Got 925 out of 928 images correctly (99.677%). Epoch loss: 0.003
#     - Training dataset. Got 957 out of 960 images correctly (99.688%). Epoch loss: 0.003
#     - Training dataset. Got 989 out of 992 images correctly (99.698%). Epoch loss: 0.003
#     - Training dataset. Got 1021 out of 1024 images correctly (99.707%). Epoch loss: 0.003
#     - Training dataset. Got 1053 out of 1056 images correctly (99.716%). Epoch loss: 0.003
#     - Training dataset. Got 1085 out of 1088 images correctly (99.724%). Epoch loss: 0.004
#     - Training dataset. Got 1117 out of 1120 images correctly (99.732%). Epoch loss: 0.004
#     - Training dataset. Got 1149 out of 1152 images correctly (99.740%). Epoch loss: 0.004
#     - Training dataset. Got 1181 out of 1184 images correctly (99.747%). Epoch loss: 0.004
#     - Training dataset. Got 1213 out of 1216 images correctly (99.753%). Epoch loss: 0.004
#     - Training dataset. Got 1245 out of 1248 images correctly (99.760%). Epoch loss: 0.004
#     - Training dataset. Got 1277 out of 1280 images correctly (99.766%). Epoch loss: 0.004
#     - Training dataset. Got 1309 out of 1312 images correctly (99.771%). Epoch loss: 0.004
#     - Training dataset. Got 1341 out of 1344 images correctly (99.777%). Epoch loss: 0.004
#     - Training dataset. Got 1373 out of 1376 images correctly (99.782%). Epoch loss: 0.004
#     - Training dataset. Got 1405 out of 1408 images correctly (99.787%). Epoch loss: 0.004
#     - Training dataset. Got 1437 out of 1440 images correctly (99.792%). Epoch loss: 0.004
#     - Training dataset. Got 1469 out of 1472 images correctly (99.796%). Epoch loss: 0.004
#     - Training dataset. Got 1500 out of 1504 images correctly (99.734%). Epoch loss: 0.005
#     - Training dataset. Got 1532 out of 1536 images correctly (99.740%). Epoch loss: 0.005
#     - Training dataset. Got 1564 out of 1568 images correctly (99.745%). Epoch loss: 0.005
#     - Training dataset. Got 1596 out of 1600 images correctly (99.750%). Epoch loss: 0.005
#     - Training dataset. Got 1628 out of 1632 images correctly (99.755%). Epoch loss: 0.005
#     - Training dataset. Got 1660 out of 1664 images correctly (99.760%). Epoch loss: 0.005
#     - Training dataset. Got 1692 out of 1696 images correctly (99.764%). Epoch loss: 0.005
#     - Training dataset. Got 1724 out of 1728 images correctly (99.769%). Epoch loss: 0.005
#     - Training dataset. Got 1756 out of 1760 images correctly (99.773%). Epoch loss: 0.005
#     - Training dataset. Got 1788 out of 1792 images correctly (99.777%). Epoch loss: 0.005
#     - Training dataset. Got 1820 out of 1824 images correctly (99.781%). Epoch loss: 0.005
#     - Training dataset. Got 1852 out of 1856 images correctly (99.784%). Epoch loss: 0.006
#     - Training dataset. Got 1884 out of 1888 images correctly (99.788%). Epoch loss: 0.006
#     - Training dataset. Got 1916 out of 1920 images correctly (99.792%). Epoch loss: 0.006
#     - Training dataset. Got 1948 out of 1952 images correctly (99.795%). Epoch loss: 0.006
#     - Training dataset. Got 1980 out of 1984 images correctly (99.798%). Epoch loss: 0.006
#     - Training dataset. Got 2012 out of 2016 images correctly (99.802%). Epoch loss: 0.006
#     - Training dataset. Got 2044 out of 2048 images correctly (99.805%). Epoch loss: 0.006
#     - Training dataset. Got 2076 out of 2080 images correctly (99.808%). Epoch loss: 0.006
#     - Training dataset. Got 2108 out of 2112 images correctly (99.811%). Epoch loss: 0.006
#     - Training dataset. Got 2140 out of 2144 images correctly (99.813%). Epoch loss: 0.006
#     - Training dataset. Got 2172 out of 2176 images correctly (99.816%). Epoch loss: 0.006
#     - Training dataset. Got 2204 out of 2208 images correctly (99.819%). Epoch loss: 0.006
#     - Training dataset. Got 2236 out of 2240 images correctly (99.821%). Epoch loss: 0.006
#     - Training dataset. Got 2268 out of 2272 images correctly (99.824%). Epoch loss: 0.006
#     - Training dataset. Got 2300 out of 2304 images correctly (99.826%). Epoch loss: 0.006
#     - Training dataset. Got 2332 out of 2336 images correctly (99.829%). Epoch loss: 0.006
#     - Training dataset. Got 2364 out of 2368 images correctly (99.831%). Epoch loss: 0.006
#     - Training dataset. Got 2396 out of 2400 images correctly (99.833%). Epoch loss: 0.006
#     - Training dataset. Got 2428 out of 2432 images correctly (99.836%). Epoch loss: 0.006
#     - Training dataset. Got 2460 out of 2464 images correctly (99.838%). Epoch loss: 0.006
#     - Training dataset. Got 2492 out of 2496 images correctly (99.840%). Epoch loss: 0.006
#     - Training dataset. Got 2524 out of 2528 images correctly (99.842%). Epoch loss: 0.006
#     - Training dataset. Got 2556 out of 2560 images correctly (99.844%). Epoch loss: 0.006
#     - Training dataset. Got 2588 out of 2592 images correctly (99.846%). Epoch loss: 0.006
#     - Training dataset. Got 2620 out of 2624 images correctly (99.848%). Epoch loss: 0.007
#     - Training dataset. Got 2652 out of 2656 images correctly (99.849%). Epoch loss: 0.007
#     - Training dataset. Got 2684 out of 2688 images correctly (99.851%). Epoch loss: 0.007
#     - Training dataset. Got 2712 out of 2716 images correctly (99.853%). Epoch loss: 0.007
# Epoch number 7
#     - Training dataset. Got 32 out of 32 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 64 out of 64 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 96 out of 96 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 128 out of 128 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 160 out of 160 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 192 out of 192 images correctly (100.000%). Epoch loss: 0.000
#     - Training dataset. Got 223 out of 224 images correctly (99.554%). Epoch loss: 0.001
#     - Training dataset. Got 255 out of 256 images correctly (99.609%). Epoch loss: 0.001
#     - Training dataset. Got 287 out of 288 images correctly (99.653%). Epoch loss: 0.001
#     - Training dataset. Got 318 out of 320 images correctly (99.375%). Epoch loss: 0.002
#     - Training dataset. Got 350 out of 352 images correctly (99.432%). Epoch loss: 0.002
#     - Training dataset. Got 382 out of 384 images correctly (99.479%). Epoch loss: 0.002
#     - Training dataset. Got 414 out of 416 images correctly (99.519%). Epoch loss: 0.002
#     - Training dataset. Got 446 out of 448 images correctly (99.554%). Epoch loss: 0.002
#     - Training dataset. Got 478 out of 480 images correctly (99.583%). Epoch loss: 0.002
#     - Training dataset. Got 510 out of 512 images correctly (99.609%). Epoch loss: 0.002
#     - Training dataset. Got 542 out of 544 images correctly (99.632%). Epoch loss: 0.002
#     - Training dataset. Got 574 out of 576 images correctly (99.653%). Epoch loss: 0.002
#     - Training dataset. Got 606 out of 608 images correctly (99.671%). Epoch loss: 0.002
#     - Training dataset. Got 638 out of 640 images correctly (99.688%). Epoch loss: 0.002
# ...
#     - Training dataset. Got 1591 out of 1600 images correctly (99.438%). Epoch loss: 0.008
#     - Training dataset. Got 1623 out of 1632 images correctly (99.449%). Epoch loss: 0.008
#     - Training dataset. Got 1655 out of 1664 images correctly (99.459%). Epoch loss: 0.008
#     - Training dataset. Got 1687 out of 1696 images correctly (99.469%). Epoch loss: 0.008
#     - Training dataset. Got 1719 out of 1728 images correctly (99.479%). Epoch loss: 0.008
#     - Training dataset. Got 1751 out of 1760 images correctly (99.489%). Epoch loss: 0.008
#     - Training dataset. Got 1783 out of 1792 images correctly (99.498%). Epoch loss: 0.009
#     - Training dataset. Got 1815 out of 1824 images correctly (99.507%). Epoch loss: 0.009
#     - Training dataset. Got 1847 out of 1856 images correctly (99.515%). Epoch loss: 0.009
#     - Training dataset. Got 1877 out of 1888 images correctly (99.417%). Epoch loss: 0.010
#     - Training dataset. Got 1908 out of 1920 images correctly (99.375%). Epoch loss: 0.011
#     - Training dataset. Got 1940 out of 1952 images correctly (99.385%). Epoch loss: 0.011
#     - Training dataset. Got 1972 out of 1984 images correctly (99.395%). Epoch loss: 0.011
#     - Training dataset. Got 2004 out of 2016 images correctly (99.405%). Epoch loss: 0.011
#     - Training dataset. Got 2036 out of 2048 images correctly (99.414%). Epoch loss: 0.011
#     - Training dataset. Got 2068 out of 2080 images correctly (99.423%). Epoch loss: 0.011
#     - Training dataset. Got 2100 out of 2112 images correctly (99.432%). Epoch loss: 0.011
#     - Training dataset. Got 2132 out of 2144 images correctly (99.440%). Epoch loss: 0.011
#     - Training dataset. Got 2164 out of 2176 images correctly (99.449%). Epoch loss: 0.011
#     - Training dataset. Got 2196 out of 2208 images correctly (99.457%). Epoch loss: 0.011
#     - Training dataset. Got 2228 out of 2240 images correctly (99.464%). Epoch loss: 0.011
#     - Training dataset. Got 2260 out of 2272 images correctly (99.472%). Epoch loss: 0.011
#     - Training dataset. Got 2292 out of 2304 images correctly (99.479%). Epoch loss: 0.011
#     - Training dataset. Got 2323 out of 2336 images correctly (99.443%). Epoch loss: 0.012
#     - Training dataset. Got 2355 out of 2368 images correctly (99.451%). Epoch loss: 0.012
#     - Training dataset. Got 2387 out of 2400 images correctly (99.458%). Epoch loss: 0.012
#     - Training dataset. Got 2419 out of 2432 images correctly (99.465%). Epoch loss: 0.012
#     - Training dataset. Got 2451 out of 2464 images correctly (99.472%). Epoch loss: 0.012
#     - Training dataset. Got 2483 out of 2496 images correctly (99.479%). Epoch loss: 0.013
#     - Training dataset. Got 2515 out of 2528 images correctly (99.486%). Epoch loss: 0.013
#     - Training dataset. Got 2547 out of 2560 images correctly (99.492%). Epoch loss: 0.013
#     - Training dataset. Got 2578 out of 2592 images correctly (99.460%). Epoch loss: 0.013
#     - Training dataset. Got 2609 out of 2624 images correctly (99.428%). Epoch loss: 0.014
#     - Training dataset. Got 2641 out of 2656 images correctly (99.435%). Epoch loss: 0.014
#     - Training dataset. Got 2673 out of 2688 images correctly (99.442%). Epoch loss: 0.014
#     - Training dataset. Got 2701 out of 2716 images correctly (99.448%). Epoch loss: 0.014
# Epoch number 10
#     - Training dataset. Got 31 out of 32 images correctly (96.875%). Epoch loss: 0.001
#     - Training dataset. Got 63 out of 64 images correctly (98.438%). Epoch loss: 0.001
#     - Training dataset. Got 95 out of 96 images correctly (98.958%). Epoch loss: 0.001
#     - Training dataset. Got 127 out of 128 images correctly (99.219%). Epoch loss: 0.001
#     - Training dataset. Got 159 out of 160 images correctly (99.375%). Epoch loss: 0.001
#     - Training dataset. Got 191 out of 192 images correctly (99.479%). Epoch loss: 0.001
#     - Training dataset. Got 223 out of 224 images correctly (99.554%). Epoch loss: 0.001
#     - Training dataset. Got 255 out of 256 images correctly (99.609%). Epoch loss: 0.001
#     - Training dataset. Got 287 out of 288 images correctly (99.653%). Epoch loss: 0.001
#     - Training dataset. Got 319 out of 320 images correctly (99.688%). Epoch loss: 0.001
#     - Training dataset. Got 351 out of 352 images correctly (99.716%). Epoch loss: 0.001
#     - Training dataset. Got 383 out of 384 images correctly (99.740%). Epoch loss: 0.001
#     - Training dataset. Got 414 out of 416 images correctly (99.519%). Epoch loss: 0.002
#     - Training dataset. Got 446 out of 448 images correctly (99.554%). Epoch loss: 0.002
#     - Training dataset. Got 478 out of 480 images correctly (99.583%). Epoch loss: 0.002
#     - Training dataset. Got 510 out of 512 images correctly (99.609%). Epoch loss: 0.002
#     - Training dataset. Got 542 out of 544 images correctly (99.632%). Epoch loss: 0.002
#     - Training dataset. Got 574 out of 576 images correctly (99.653%). Epoch loss: 0.002
#     - Training dataset. Got 606 out of 608 images correctly (99.671%). Epoch loss: 0.002
#     - Training dataset. Got 638 out of 640 images correctly (99.688%). Epoch loss: 0.002
#     - Training dataset. Got 670 out of 672 images correctly (99.702%). Epoch loss: 0.002
#     - Training dataset. Got 702 out of 704 images correctly (99.716%). Epoch loss: 0.002
#     - Training dataset. Got 734 out of 736 images correctly (99.728%). Epoch loss: 0.002
#     - Training dataset. Got 766 out of 768 images correctly (99.740%). Epoch loss: 0.002
#     - Training dataset. Got 798 out of 800 images correctly (99.750%). Epoch loss: 0.003
#     - Training dataset. Got 830 out of 832 images correctly (99.760%). Epoch loss: 0.003
#     - Training dataset. Got 862 out of 864 images correctly (99.769%). Epoch loss: 0.003
#     - Training dataset. Got 894 out of 896 images correctly (99.777%). Epoch loss: 0.003
#     - Training dataset. Got 926 out of 928 images correctly (99.784%). Epoch loss: 0.003
#     - Training dataset. Got 958 out of 960 images correctly (99.792%). Epoch loss: 0.003
#     - Training dataset. Got 989 out of 992 images correctly (99.698%). Epoch loss: 0.003
#     - Training dataset. Got 1021 out of 1024 images correctly (99.707%). Epoch loss: 0.003
#     - Training dataset. Got 1053 out of 1056 images correctly (99.716%). Epoch loss: 0.003
#     - Training dataset. Got 1085 out of 1088 images correctly (99.724%). Epoch loss: 0.003
#     - Training dataset. Got 1117 out of 1120 images correctly (99.732%). Epoch loss: 0.003
#     - Training dataset. Got 1149 out of 1152 images correctly (99.740%). Epoch loss: 0.003
#     - Training dataset. Got 1181 out of 1184 images correctly (99.747%). Epoch loss: 0.003
#     - Training dataset. Got 1213 out of 1216 images correctly (99.753%). Epoch loss: 0.004
#     - Training dataset. Got 1245 out of 1248 images correctly (99.760%). Epoch loss: 0.004
#     - Training dataset. Got 1277 out of 1280 images correctly (99.766%). Epoch loss: 0.004
#     - Training dataset. Got 1309 out of 1312 images correctly (99.771%). Epoch loss: 0.004
#     - Training dataset. Got 1341 out of 1344 images correctly (99.777%). Epoch loss: 0.004
#     - Training dataset. Got 1373 out of 1376 images correctly (99.782%). Epoch loss: 0.004
#     - Training dataset. Got 1405 out of 1408 images correctly (99.787%). Epoch loss: 0.004
#     - Training dataset. Got 1437 out of 1440 images correctly (99.792%). Epoch loss: 0.004
#     - Training dataset. Got 1469 out of 1472 images correctly (99.796%). Epoch loss: 0.004
#     - Training dataset. Got 1501 out of 1504 images correctly (99.801%). Epoch loss: 0.004
#     - Training dataset. Got 1533 out of 1536 images correctly (99.805%). Epoch loss: 0.004
#     - Training dataset. Got 1565 out of 1568 images correctly (99.809%). Epoch loss: 0.004
#     - Training dataset. Got 1597 out of 1600 images correctly (99.812%). Epoch loss: 0.004
#     - Training dataset. Got 1629 out of 1632 images correctly (99.816%). Epoch loss: 0.004
#     - Training dataset. Got 1661 out of 1664 images correctly (99.820%). Epoch loss: 0.004
#     - Training dataset. Got 1692 out of 1696 images correctly (99.764%). Epoch loss: 0.004
#     - Training dataset. Got 1724 out of 1728 images correctly (99.769%). Epoch loss: 0.004
#     - Training dataset. Got 1756 out of 1760 images correctly (99.773%). Epoch loss: 0.004
#     - Training dataset. Got 1788 out of 1792 images correctly (99.777%). Epoch loss: 0.004
#     - Training dataset. Got 1820 out of 1824 images correctly (99.781%). Epoch loss: 0.005
#     - Training dataset. Got 1852 out of 1856 images correctly (99.784%). Epoch loss: 0.005
#     - Training dataset. Got 1883 out of 1888 images correctly (99.735%). Epoch loss: 0.005
#     - Training dataset. Got 1915 out of 1920 images correctly (99.740%). Epoch loss: 0.005
#     - Training dataset. Got 1947 out of 1952 images correctly (99.744%). Epoch loss: 0.006
#     - Training dataset. Got 1979 out of 1984 images correctly (99.748%). Epoch loss: 0.006
#     - Training dataset. Got 2011 out of 2016 images correctly (99.752%). Epoch loss: 0.006
#     - Training dataset. Got 2043 out of 2048 images correctly (99.756%). Epoch loss: 0.006
#     - Training dataset. Got 2075 out of 2080 images correctly (99.760%). Epoch loss: 0.006
#     - Training dataset. Got 2107 out of 2112 images correctly (99.763%). Epoch loss: 0.006
#     - Training dataset. Got 2139 out of 2144 images correctly (99.767%). Epoch loss: 0.006
#     - Training dataset. Got 2171 out of 2176 images correctly (99.770%). Epoch loss: 0.006
#     - Training dataset. Got 2203 out of 2208 images correctly (99.774%). Epoch loss: 0.006
#     - Training dataset. Got 2235 out of 2240 images correctly (99.777%). Epoch loss: 0.006
#     - Training dataset. Got 2267 out of 2272 images correctly (99.780%). Epoch loss: 0.006
#     - Training dataset. Got 2299 out of 2304 images correctly (99.783%). Epoch loss: 0.006
#     - Training dataset. Got 2331 out of 2336 images correctly (99.786%). Epoch loss: 0.006
#     - Training dataset. Got 2363 out of 2368 images correctly (99.789%). Epoch loss: 0.006
#     - Training dataset. Got 2395 out of 2400 images correctly (99.792%). Epoch loss: 0.006
#     - Training dataset. Got 2427 out of 2432 images correctly (99.794%). Epoch loss: 0.006
#     - Training dataset. Got 2459 out of 2464 images correctly (99.797%). Epoch loss: 0.006
#     - Training dataset. Got 2491 out of 2496 images correctly (99.800%). Epoch loss: 0.006
#     - Training dataset. Got 2523 out of 2528 images correctly (99.802%). Epoch loss: 0.006
#     - Training dataset. Got 2555 out of 2560 images correctly (99.805%). Epoch loss: 0.006
#     - Training dataset. Got 2587 out of 2592 images correctly (99.807%). Epoch loss: 0.006
#     - Training dataset. Got 2619 out of 2624 images correctly (99.809%). Epoch loss: 0.006
#     - Training dataset. Got 2651 out of 2656 images correctly (99.812%). Epoch loss: 0.006
#     - Training dataset. Got 2683 out of 2688 images correctly (99.814%). Epoch loss: 0.006
#     - Training dataset. Got 2710 out of 2716 images correctly (99.779%). Epoch loss: 0.007
#     - Testing dataset. Got 2714 out of 2716 images correctly (99.926%)
# Finished
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
checkpoint = torch.load('model_best_checkpoint.pth.tar') # load checkpoint

# %%
print(checkpoint['epoch'])
print(checkpoint['comments'])
print(checkpoint['best accuracy'])
# Out:
# 10
# very cool model!
# 99.92636229749631

# %%
import torch.optim as optim
import torchvision.models as models
import torch.nn as nn
import torch
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load folders from the corrected path
train_dataset = ImageFolder(root=train_dataset_path, transform=train_transforms)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

# Dynamically extract all 5 classes (Background, Bird, Palm, Spider, Wolf)
classes = train_dataset.classes
number_of_classes = len(classes)

print("--- VERIFYING DETECTED SYSTEM DIRECTORIES ---")
print(f"Detected Classes on drive: {classes}")
print(f"Index Mapping: {train_dataset.class_to_idx}")
print("--------------------------------------------\n")

# Load a clean pre-trained ResNet18 backbone
resnet18_model = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = resnet18_model.fc.in_features

# Set output channels to 5
resnet18_model.fc = nn.Linear(num_ftrs, number_of_classes) 
resnet18_model = resnet18_model.to(device)

criterion = nn.CrossEntropyLoss() 
optimizer = optim.Adam(resnet18_model.parameters(), lr=0.001)

print(f"Training a 5-class model across {len(train_dataset)} total images...")
resnet18_model.train()

for epoch in range(5):
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = resnet18_model(images)
        loss = criterion(outputs, labels) 
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    print(f"Epoch {epoch+1}/5 finished. Loss: {running_loss/len(train_loader):.4f}")

torch.save(resnet18_model, 'best_model.pth')
print("\nSuccess! 5-Class Model trained and saved as best_model.pth!")
# Out:
# --- VERIFYING DETECTED SYSTEM DIRECTORIES ---
# Detected Classes on drive: ['Background', 'Bird', 'Moose', 'Palm', 'Spider', 'Swan', 'Wolf']
# Index Mapping: {'Background': 0, 'Bird': 1, 'Moose': 2, 'Palm': 3, 'Spider': 4, 'Swan': 5, 'Wolf': 6}
# --------------------------------------------
#
# Training a 5-class model across 2716 total images...
# Epoch 1/5 finished. Loss: 0.3082
# Epoch 2/5 finished. Loss: 0.1240
# Epoch 3/5 finished. Loss: 0.1006
# Epoch 4/5 finished. Loss: 0.0838
# Epoch 5/5 finished. Loss: 0.0521
#
# Success! 5-Class Model trained and saved as best_model.pth!
